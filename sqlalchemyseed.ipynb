# %%
import json
import jsonschema
import sqlalchemyseed

# with open('src/sqlalchemyseed/schemas/parent.json', 'r', encoding='utf-8') as file:
#     schema = json.loads(file.read())

schema = sqlalchemyseed.load_entities_from_json(
    'src/sqlalchemyseed/schemas/schema.json'
)


instance = [
    {
        "model": "models.User",
        "data": [
            {
                "$rel": {
                    "location": {
                        # "model": "44545",
                        "data": [
                            {
                                "name": "New York",
                                "$rel": {
                                    "country": [
                                        {
                                            # "model": "4343",
                                            "data": {}
                                        },
                                    ],
                                }
                            },
                        ],
                    },
                },
            },
            {
                "name": "John Doe",
            },
        ],
    },
    {
        "data": {
            "name": "John Doe",
        }
    }
]

jsonschema.Draft7Validator(schema).validate(instance)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# /workspaces/sqlalchemyseed/sqlalchemyseed.ipynb Cell 1' in <cell line: 49>()
#       <a href='vscode-notebook-cell://codespaces%2Bjedymatt-sqlalchemyseed-x6v44w9j2pv9/workspaces/sqlalchemyseed/sqlalchemyseed.ipynb#ch0000000vscode-remote?line=7'>8</a> schema = sqlalchemyseed.load_entities_from_json(
#       <a href='vscode-notebook-cell://codespaces%2Bjedymatt-sqlalchemyseed-x6v44w9j2pv9/workspaces/sqlalchemyseed/sqlalchemyseed.ipynb#ch0000000vscode-remote?line=8'>9</a>     'src/sqlalchemyseed/schemas/schema.json'
#      <a href='vscode-notebook-cell://codespaces%2Bjedymatt-sqlalchemyseed-x6v44w9j2pv9/workspaces/sqlalchemyseed/sqlalchemyseed.ipynb#ch0000000vscode-remote?line=9'>10</a> )
#      <a href='vscode-notebook-cell://codespaces%2Bjedymatt-sqlalchemyseed-x6v44w9j2pv9/workspaces/sqlalchemyseed/sqlalchemyseed.ipynb#ch0000000vscode-remote?line=12'>13</a> instance = [
#      <a href='vscode-notebook-cell://codespaces%2Bjedymatt-sqlalchemyseed-x6v44w9j2pv9/workspaces/sqlalchemyseed/sqlalchemyseed.ipynb#ch0000000vscode-remote?line=13'>14</a>     {
#      <a href='vscode-notebook-cell://codespaces%2Bjedymatt-sqlalchemyseed-x6v44w9j2pv9/workspaces/sqlalchemyseed/sqlalchemyseed.ipynb#ch0000000vscode-remote?line=14'>15</a>         "model": "models.User",
#    (...)
#      <a href='vscode-notebook-cell://codespaces%2Bjedymatt-sqlalchemyseed-x6v44w9j2pv9/workspaces/sqlalchemyseed/sqlalchemyseed.ipynb#ch0000000vscode-remote?line=45'>46</a>     }
#      <a href='vscode-notebook-cell://codespaces%2Bjedymatt-sqlalchemyseed-x6v44w9j2pv9/workspaces/sqlalchemyseed/sqlalchemyseed.ipynb#ch0000000vscode-remote?line=46'>47</a> ]
# ---> <a href='vscode-notebook-cell://codespaces%2Bjedymatt-sqlalchemyseed-x6v44w9j2pv9/workspaces/sqlalchemyseed/sqlalchemyseed.ipynb#ch0000000vscode-remote?line=48'>49</a> jsonschema.Draft7Validator(schema).validate(instance)
#
# File /opt/python/3.10.4/lib/python3.10/site-packages/jsonschema/validators.py:267, in create.<locals>.Validator.validate(self, *args, **kwargs)
#     <a href='file:///opt/python/3.10.4/lib/python3.10/site-packages/jsonschema/validators.py?line=264'>265</a> def validate(self, *args, **kwargs):
#     <a href='file:///opt/python/3.10.4/lib/python3.10/site-packages/jsonschema/validators.py?line=265'>266</a>     for error in self.iter_errors(*args, **kwargs):
# --> <a href='file:///opt/python/3.10.4/lib/python3.10/site-packages/jsonschema/validators.py?line=266'>267</a>         raise error
#
# ValidationError: [{'model': 'models.User', 'data': [{'$rel': {'location': {'data': [{'name': 'New York', '$rel': {'country': [{'data': {}}]}}]}}}, {'name': 'John Doe'}]}, {'data': {'name': 'John Doe'}}] is not valid under any of the given schemas
#
# Failed validating 'oneOf' in schema:
#     {'$id': 'http://example.com/example.json',
#      '$schema': 'https://json-schema.org/draft-07/schema',
#      'definitions': {'child_entity': {'oneOf': [{'required': ['data']},
#                                                 {'required': ['filter']}],
#                                       'optional': ['model'],
#                                       'properties': {'data': {'$ref': '#/definitions/entity/properties/data'},
#                                                      'filter': {'$ref': '#/definitions/entity/properties/filter'},
#                                                      'model': {'type': 'string'}},
#                                       'title': 'A Schema',
#                                       'type': 'object'},
#                      'child_entity_group': {'items': {'$ref': '#/definitions/child_entity'},
#                                             'type': 'array'},
#                      'entity': {'definitions': {'child_entity': {'oneOf': [{'required': ['data']},
#                                                                            {'required': ['filter']}],
#                                                                  'optional': ['model'],
#                                                                  'properties': {'data': {'$ref': '#/definitions/entity/properties/data'},
#                                                                                 'filter': {'$ref': '#/definitions/entity/properties/filter'},
#                                                                                 'model': {'type': 'string'}},
#                                                                  'title': 'The '
#                                                                           'child_entity '
#                                                                           'Schema',
#                                                                  'type': 'object'},
#                                                 'child_group_entity': {'items': {'$ref': '#/definitions/entity/definitions/child_entity'},
#                                                                        'type': 'array'},
#                                                 'data_container': {'properties': {'$rel': {'additionalProperties': {'anyOf': [{'$ref': '#/definitions/entity/definitions/child_entity',
#                                                                                                                                'type': 'object'},
#                                                                                                                               {'$ref': '#/definitions/entity/definitions/child_group_entity',
#                                                                                                                                'type': 'array'}]},
#                                                                                            'default': {},
#                                                                                            'title': 'The '
#                                                                                                     '$rel '
#                                                                                                     'Schema',
#                                                                                            'type': 'object'}},
#                                                                    'title': 'The '
#                                                                             'data '
#                                                                             'Schema',
#                                                                    'type': 'object'}},
#                                 'oneOf': [{'required': ['data']},
#                                           {'required': ['filter']}],
#                                 'properties': {'data': {'oneOf': [{'$ref': '#/definitions/entity/definitions/data_container'},
#                                                                   {'items': {'$ref': '#/definitions/entity/definitions/data_container'},
#                                                                    'type': 'array'}]},
#                                                'filter': {'oneOf': [{'$ref': '#/definitions/entity/definitions/data_container'},
#                                                                     {'items': {'$ref': '#/definitions/entity/definitions/data_container'},
#                                                                      'type': 'array'}]},
#                                                'model': {'title': 'The '
#                                                                   'model '
#                                                                   'Schema',
#                                                          'type': 'string'}},
#                                 'required': ['model'],
#                                 'title': 'A Schema',
#                                 'type': 'object'},
#                      'entity_group': {'items': {'$ref': '#/definitions/entity'},
#                                       'type': 'array'}},
#      'oneOf': [{'$ref': '#/definitions/entity'},
#                {'$ref': '#/definitions/entity_group'}],
#      'title': 'Root Schema'}
#
# On instance:
#     [{'data': [{'$rel': {'location': {'data': [{'$rel': {'country': [{'data': {}}]},
#                                                 'name': 'New York'}]}}},
#                {'name': 'John Doe'}],
#       'model': 'models.User'},
#      {'data': {'name': 'John Doe'}}]
